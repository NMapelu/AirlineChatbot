# %% [markdown]
# <a href="https://colab.research.google.com/github/NMapelu/AirlineChatbot/blob/main/notebooks/00_bootstrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls /content
# Out:
# AirlineChatbot	drive  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

DRIVE_ROOT = "/content/drive/MyDrive/AirlineChatbot"

for sub in ["data/raw", "data/processed", "checkpoints", "outputs", "secrets"]:
    os.makedirs(f"{DRIVE_ROOT}/{sub}", exist_ok=True)

print("Drive folders ready at:", DRIVE_ROOT)
# !ls -R {DRIVE_ROOT}
# Out:
# Drive folders ready at: /content/drive/MyDrive/AirlineChatbot
# /content/drive/MyDrive/AirlineChatbot:
# checkpoints  data  outputs  secrets
#
# /content/drive/MyDrive/AirlineChatbot/checkpoints:
#
# /content/drive/MyDrive/AirlineChatbot/data:
# processed  raw
#
# /content/drive/MyDrive/AirlineChatbot/data/processed:
#
# /content/drive/MyDrive/AirlineChatbot/data/raw:
#
# /content/drive/MyDrive/AirlineChatbot/outputs:
#
# /content/drive/MyDrive/AirlineChatbot/secrets:

# %%
import os

REPO_URL = "https://github.com/NMapelu/AirlineChatbot.git"
PROJECT_DIR = "/content/AirlineChatbot"

if not os.path.exists(PROJECT_DIR):
    # !git clone {REPO_URL} {PROJECT_DIR}
else:
    # !cd {PROJECT_DIR} && git pull

os.chdir(PROJECT_DIR)
print("Working directory:", os.getcwd())
# !ls -la
# Out:
# Already up to date.
# Working directory: /content/AirlineChatbot
# total 24
# drwxr-xr-x 3 root root 4096 Sep 18 00:54 .
# drwxr-xr-x 1 root root 4096 Sep 18 00:54 ..
# drwxr-xr-x 8 root root 4096 Sep 18 00:56 .git
# -rw-r--r-- 1 root root  289 Sep 18 00:54 .gitignore
# -rw-r--r-- 1 root root   16 Sep 18 00:54 README.md
# -rw-r--r-- 1 root root   42 Sep 18 00:54 requirements.txt

# %%
# !pip install -q -r requirements.txt

# %%
import os

os.environ["PROJECT_DRIVE"] = "/content/drive/MyDrive/AirlineChatbot"
os.environ["PROJECT_LOCAL"] = "/content/AirlineChatbot"

print("PROJECT_DRIVE =", os.environ["PROJECT_DRIVE"])
print("PROJECT_LOCAL =", os.environ["PROJECT_LOCAL"])
# Out:
# PROJECT_DRIVE = /content/drive/MyDrive/AirlineChatbot
# PROJECT_LOCAL = /content/AirlineChatbot

# %%
import os

print("Colab working dir :", os.getcwd())
print("Repo contents     :", os.listdir("/content/AirlineChatbot"))
print("Drive root exists :", os.path.exists("/content/drive/MyDrive/AirlineChatbot"))
print("Drive subfolders  :", os.listdir("/content/drive/MyDrive/AirlineChatbot"))
# Out:
# Colab working dir : /content/AirlineChatbot
# Repo contents     : ['README.md', '.git', 'requirements.txt', '.gitignore']
# Drive root exists : True
# Drive subfolders  : ['data', 'checkpoints', 'outputs', 'secrets']
